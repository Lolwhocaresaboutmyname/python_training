# %% [markdown]
# <a href="https://colab.research.google.com/github/Lolwhocaresaboutmyname/python_training/blob/main/MORESTUDENTSORTING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Home Assignments:

# %%
students = [67,74,82,6,99,73]
for i in range(1,7):
  if(students[i-1] >= 70):
    print("Student",i,"passed the exam.")
  else:
    print("Student",i,"failed the exam.")
# Out:
# Student 1 failed the exam.
# Student 2 passed the exam.
# Student 3 passed the exam.
# Student 4 failed the exam.
# Student 5 passed the exam.
# Student 6 passed the exam.
