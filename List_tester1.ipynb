# %% [markdown]
# <a href="https://colab.research.google.com/github/Lolwhocaresaboutmyname/python_training/blob/main/List_tester1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Home Assignments:

# %%
ball = ["6", "7", "9", "or"]
print(len(ball))
# Out:
# 3

# %%
LISTETH = ["Anish", "Sheikh", "maus"]
print(LISTETH)
print(LISTETH[0], LISTETH[1], LISTETH[2])
# Out:
# ['Anish', 'Sheikh', 'maus']
# Anish Sheikh maus

# %%
listshape = ["balls", "pyramids", "cones"]
listnum = [8751, 3687, 6762, 1769]
listbool = ["True", "False"]
print(listshape)
print(listnum)
print(listbool)
# Out:
# ['balls', 'pyramids', 'cones']
# [8751, 3687, 6762, 1769]
# ['True', 'False']
