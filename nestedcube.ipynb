# %% [markdown]
# <a href="https://colab.research.google.com/github/Lolwhocaresaboutmyname/python_training/blob/main/nestedcube.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Home Assignments:

# %%
for i in range(1, 9):
  for j in range(1, 9):
    print("* ", end=" ")
  print()
# Out:
# *  *  *  *  *  *  *  *
# *  *  *  *  *  *  *  *
# *  *  *  *  *  *  *  *
# *  *  *  *  *  *  *  *
# *  *  *  *  *  *  *  *
# *  *  *  *  *  *  *  *
# *  *  *  *  *  *  *  *
# *  *  *  *  *  *  *  *
