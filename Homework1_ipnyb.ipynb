# %% [markdown]
# <a href="https://colab.research.google.com/github/Lolwhocaresaboutmyname/python_training/blob/main/Homework1_ipnyb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Home Assignments:

# %%
score = int(input("Input the score:"))
minscore = int(input("Input how much they need to pass:"))
if score >= minscore:
    print("Pass.")
else:
    print("Fail.")
# Out:
# Input the score:69
# Input how much they need to pass:67
# Pass

# %%
number = int(input("Input a number:"))
if number % 2 == 0:
    print("Even.")
else:
    print("Odd.")
