# %% [markdown]
# <a href="https://colab.research.google.com/github/Lolwhocaresaboutmyname/python_training/blob/main/ElifWork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Home Assignments:

# %% [markdown]
# Homework:
# Write something that checks if a number is even or odd.
# Input a type of traffic light and explain what to do when seeing it.

# %%
# strings and ints kinda wrecked this
number = int(input("Enter thy number:"))
if number % 2 == 0:
  print("It is even.")
else:
  print("It is odd.")
# Out:
# Enter thy number:67
# It is odd.

# %%
# this task perplexes me, despite being easy.
number = int(input("1. Green Light - 2. Red Light - 3. Yellow Light:"))
if number == 1:
  print("A greenlight means you can drive past, as long as you follow all the other checks and balances.")
elif number == 2:
  print("It's red, stick in place.")
elif number == 3:
  print("It's about to turn red, if you're really close, go ahead, otherwise, start slowing down.")
else:
  print("... What?")
# Out:
# 1. Green Light - 2. Red Light - 3. Yellow Light:2
# It's red, stick in place.
