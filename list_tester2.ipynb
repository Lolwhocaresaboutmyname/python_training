# %% [markdown]
# <a href="https://colab.research.google.com/github/Lolwhocaresaboutmyname/python_training/blob/main/list_tester2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Home Assignments:

# %%
student = {
    "name": "Anish",
    "age": "14",
    "grade": "9",
    "class": "9C",
    "electives": "Digi Tech and Theatre"
}
print(student[""])
# Out:
# Digi Tech and Theatre

# %%
student["grade"] = 6
print(student)
# Out:
# {'name': 'Anish', 'age': '14', 'grade': 6}
