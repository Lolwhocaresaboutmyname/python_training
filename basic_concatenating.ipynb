# %% [markdown]
# The task was to add up three numbers.

# %%
print("Input three numbers to add them up.")
num1 = float(input("Add your first number:"))
num2 = float(input("Add your second number:"))
num3 = float(input("Add your third number:"))
print("Sum =", num1+num2+num3)

# %%
name = (input("Input your name:"))
age = (input("Input your age:"))
print("Hello", name + ", you are", age, "years old.")
# Out:
# Input your name:Anish
# Input your age:31
# Hello Anish, you are 31 years old.
